# %% [markdown]
# ### Preparación del Entorno

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import modulos as mod

# %% [markdown]
# ### Carga del Dataset

# %%
data = pd.read_csv('Grades.csv', sep = ",", encoding='latin-1')
dataset = data

# %%
dataset.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Exploración de la Data

# %%
dataset.shape
# Out:
# (649, 33)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %% [markdown]
# ### Revisión datos de la Variables Independientes

# %%
dataset['G3'].value_counts()
# Out:
# 11    104
# 10     97
# 13     82
# 12     72
# 14     63
# 15     49
# 16     36
# 9      35
# 8      35
# 17     29
# 18     15
# 0      15
# 7      10
# 6       3
# 19      2
# 1       1
# 5       1
# Name: G3, dtype: int64

# %%
dataset['age'].value_counts()
# Out:
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: age, dtype: int64

# %%
dataset['Mjob'].value_counts()
# Out:
# other       258
# services    136
# at_home     135
# teacher      72
# health       48
# Name: Mjob, dtype: int64

# %%
dataset['famrel'].value_counts()
# Out:
# 4    317
# 5    180
# 3    101
# 2     29
# 1     22
# Name: famrel, dtype: int64

# %%
dataset['Fedu'].value_counts()
# Out:
# 2    209
# 1    174
# 3    131
# 4    128
# 0      7
# Name: Fedu, dtype: int64

# %% [markdown]
# ### Descarte de Columnas no útilies

# %%
#dataset = dataset.drop(['Precio', 'Cantidad', 'Almacen_Recurrente', 'Fecha_Emision', 'Vehiculo', 'Cliente'], axis=1)

# %% [markdown]
# #### Luego de revisar la data y determinar que viene bastante consitente y completa todavía no se hace un descarte de ninguna de las variables.

# %% [markdown]
# ### Clasificación de Columnas

# %%
dataset.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# #### Obtener el tipo de datos de las columnas del dataframe

# %%
categoric_vars, discrete_vars , continues_vars = mod.getColumnsDataTypes(df=dataset)

# %% [markdown]
# ### Estadísticas de las Variables

# %% [markdown]
# #### Variables Discretas

# %%
mod.stats(dataset, vars = discrete_vars)
# Out:
# Estadísticas de age {'Media': 16.74, 'Max': 22, 'Min': 15, 'Desv': 1.22, 'Rango': 2}
# Estadísticas de Medu {'Media': 2.51, 'Max': 4, 'Min': 0, 'Desv': 1.13, 'Rango': 2}
# Estadísticas de Fedu {'Media': 2.31, 'Max': 4, 'Min': 0, 'Desv': 1.1, 'Rango': 2}
# Estadísticas de traveltime {'Media': 1.57, 'Max': 4, 'Min': 1, 'Desv': 0.75, 'Rango': 1}
# Estadísticas de studytime {'Media': 1.93, 'Max': 4, 'Min': 1, 'Desv': 0.83, 'Rango': 1}
# Estadísticas de failures {'Media': 0.22, 'Max': 3, 'Min': 0, 'Desv': 0.59, 'Rango': 0}
# Estadísticas de famrel {'Media': 3.93, 'Max': 5, 'Min': 1, 'Desv': 0.96, 'Rango': 1}
# Estadísticas de freetime {'Media': 3.18, 'Max': 5, 'Min': 1, 'Desv': 1.05, 'Rango': 1}
# Estadísticas de goout {'Media': 3.18, 'Max': 5, 'Min': 1, 'Desv': 1.18, 'Rango': 2}
# Estadísticas de Dalc {'Media': 1.5, 'Max': 5, 'Min': 1, 'Desv': 0.92, 'Rango': 1}
# Estadísticas de Walc {'Media': 2.28, 'Max': 5, 'Min': 1, 'Desv': 1.28, 'Rango': 2}
# ...

# %% [markdown]
# #### Variables Continuas

# %%
mod.stats(dataset, vars = continues_vars)

# %% [markdown]
# No hay variables cuantitativas que tengan al menos 30 valores diferentes para considerarla como continua, por lo que solamente hay variables discretas.

# %% [markdown]
# ### Graficación de los Datos

# %%
mod.plotCategoricalVals(dataset, categoric_vars, y='G3')

# %% [markdown]
# ### Variables Continuas

# %%
mod.plotVars(dataset, vars =continues_vars)

# %% [markdown]
# ### Variables Discretas

# %%
mod.plotVars(dataset, vars =discrete_vars)

# %% [markdown]
# ### Resumen de la Exploración

# %% [markdown]
# La data viene bastante limpia, consistente y completa.
#
# La mayoría de las variables son cuantitativas de tipo discreto y el resto son categoricas. No hay variables continuas
#
# En este primer análisis no se descartó ninguna variable.
#
# Las estadísticas y las gráficas de las variables permiten apreciar que los datos se encuentran bastante centrados con poca varianza o sesgos.
